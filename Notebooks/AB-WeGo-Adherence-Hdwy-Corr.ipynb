# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as st

# %%
headway_df = pd.read_excel('..\Data\Headway Data, 8-1-2023 to 9-30-2023.xlsx')

# %%
headway_df.iloc[0:30,0:20]
# Out:
#     CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID       DATE  ROUTE_ABBR  \
# 0     120230801             1      99457890 2023-08-01          22
# 1     120230801             1      99457891 2023-08-01          22
# 2     120230801             1      99457892 2023-08-01          22
# 3     120230801             1      99457893 2023-08-01          22
# 4     120230801             1      99457894 2023-08-01          22
# 5     120230801             1      99457895 2023-08-01          22
# 6     120230801             1      99457896 2023-08-01          22
# 7     120230801             1      99457897 2023-08-01          22
# 8     120230801             1      99457898 2023-08-01          22
# 9     120230801             1      99457899 2023-08-01          22
# 10    120230801             1      99457900 2023-08-01          22
# 11    120230801             1      99457901 2023-08-01          22
# 12    120230801             1      99457902 2023-08-01          22
# ...

# %%
headway_df.iloc[0:30,20:30]
# Out:
#     ACTUAL_HDWY  HDWY_DEV  ADJUSTED_EARLY_COUNT  ADJUSTED_LATE_COUNT  \
# 0           NaN       NaN                     0                    0
# 1           NaN       NaN                     0                    0
# 2           NaN       NaN                     0                    0
# 3           NaN       NaN                     0                    0
# 4           NaN       NaN                     0                    0
# 5           NaN       NaN                     0                    0
# 6           NaN       NaN                     0                    0
# 7     37.666666  2.666666                     0                    0
# 8     36.966666  1.966666                     0                    0
# 9     14.516666 -0.483334                     0                    0
# 10          NaN       NaN                     0                    0
# 11    12.833333 -2.166667                     0                    0
# 12    11.116666 -3.883334                     1                    0
# ...

# %%
headway_df.nunique()
# Out:
# CALENDAR_ID                      61
# SERVICE_ABBR                      3
# ADHERENCE_ID                 350328
# DATE                             61
# ROUTE_ABBR                        8
# BLOCK_ABBR                      102
# OPERATOR                        341
# TRIP_ID                        3987
# OVERLOAD_ID                       5
# ROUTE_DIRECTION_NAME              2
# TIME_POINT_ABBR                  61
# ROUTE_STOP_SEQUENCE              17
# TRIP_EDGE                         3
# LATITUDE                         74
# LONGITUDE                        73
# SCHEDULED_TIME                 1221
# ACTUAL_ARRIVAL_TIME           69864
# ACTUAL_DEPARTURE_TIME         70411
# ADHERENCE                      3765
# SCHEDULED_HDWY                   70
# ACTUAL_HDWY                    4974
# HDWY_DEV                       4217
# ADJUSTED_EARLY_COUNT              2
# ADJUSTED_LATE_COUNT               2
# ADJUSTED_ONTIME_COUNT             2
# STOP_CANCELLED                    2
# ...

# %%
headway_df[['ADHERENCE','SCHEDULED_HDWY','ACTUAL_HDWY','HDWY_DEV']].corr()
# Out:
#                 ADHERENCE  SCHEDULED_HDWY  ACTUAL_HDWY  HDWY_DEV
# ADHERENCE        1.000000        0.034318    -0.074719 -0.206794
# SCHEDULED_HDWY   0.034318        1.000000     0.862633  0.041296
# ACTUAL_HDWY     -0.074719        0.862633     1.000000  0.541023
# HDWY_DEV        -0.206794        0.041296     0.541023  1.000000

# %%
r = headway_df[['ADHERENCE','HDWY_DEV']].corr()['ADHERENCE']['HDWY_DEV']
print('r = ' + str(r))
print('R^2 = ' + str(r**2))
# Out:
# r = -0.20679395520064747
# R^2 = 0.042763739907527396

# %%
rawplot = sns.regplot(data=headway_df[headway_df['HDWY_DEV']!=np.inf], x= 'ADHERENCE', y='HDWY_DEV', line_kws={'color':'grey'})
slope, intercept, r, p, sterr = st.linregress(x=rawplot.get_lines()[0].get_xdata(),y=rawplot.get_lines()[0].get_ydata())
print(f'HDWY_DEV = {round(slope,2)}*ADHERENCE + {round(intercept,2)}')
rawplot;
# Out:
# HDWY_DEV = -0.23*ADHERENCE + -0.28

# %%
headway_df200 = headway_df[(headway_df['ADHERENCE']>-200) & (headway_df['HDWY_DEV']<200)]

# %%
subsetplot = sns.regplot(data=headway_df200[headway_df200['HDWY_DEV']!=np.inf], x= 'ADHERENCE', y='HDWY_DEV', line_kws={'color':'grey'})
slope, intercept, r, p, sterr = st.linregress(x=subsetplot.get_lines()[0].get_xdata(),y=subsetplot.get_lines()[0].get_ydata())
print(f'HDWY_DEV = {round(slope,2)}*ADHERENCE + {round(intercept,2)}')
subsetplot;
# Out:
# HDWY_DEV = -0.32*ADHERENCE + -0.63

# %%
r = headway_df200[['ADHERENCE','HDWY_DEV']].corr()['ADHERENCE']['HDWY_DEV']
print('r = ' + str(r))
print('R^2 = ' + str(r**2))
# Out:
# r = -0.2705726018094982
# R^2 = 0.07320953284996128

# %%
sns.scatterplot(data=headway_df, x= 'ADHERENCE', y='SCHEDULED_HDWY');

# %%
sns.scatterplot(data=headway_df, x= 'ADHERENCE', y='ACTUAL_HDWY');

# %%
sns.scatterplot(data=headway_df, x= 'ADHERENCE', y='HDWY_DEV');

# %%
ishdwy_dev_normal = st.normaltest(headway_df['HDWY_DEV'][headway_df['HDWY_DEV'].notnull()])
ishdwy_dev_normal_pvalue=ishdwy_dev_normal[1]

if ishdwy_dev_normal_pvalue>=0.05:
    print('The p value was {:.3f}. The null hypothesis of the normality test was not rejected. The headway deviation distribution can be assumed to be normal.'.format(ishdwy_dev_normal_pvalue))
else:
    print('The p value was {:.3f}. The null hypothesis of the normality test was rejected. The headway deviation distribution cannot be assumed to be normal.'.format(ishdwy_dev_normal_pvalue))
# Out:
# The p value was 0.000. The null hypothesis of the normality test was rejected. The headway deviation distribution cannot be assumed to be normal.

# %%
isadherence_normal = st.normaltest(headway_df['ADHERENCE'][headway_df['ADHERENCE'].notnull()])
isadherence_normal_pvalue=isadherence_normal[1]

if isadherence_normal_pvalue>=0.05:
    print('The p value was {:.3f}. The null hypothesis of the normality test was not rejected. The headway deviation distribution can be assumed to be normal.'.format(isadherence_normal_pvalue))
else:
    print('The p value was {:.3f}. The null hypothesis of the normality test was rejected. The headway deviation distribution cannot be assumed to be normal.'.format(isadherence_normal_pvalue))
# Out:
# The p value was 0.000. The null hypothesis of the normality test was rejected. The headway deviation distribution cannot be assumed to be normal.

# %%
headway_df['LOG_ADHERENCE']= np.log(headway_df['ADHERENCE'])
headway_df['LOG_HDWY_DEV'] = np.log(headway_df['HDWY_DEV'])
headway_df['LOG_SCHEDULED_HDWY'] = np.log(headway_df['SCHEDULED_HDWY'])
headway_df['LOG_ACTUAL_HDWY'] = np.log(headway_df['ACTUAL_HDWY'])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# ...

# %%
sns.scatterplot(data=headway_df, x= 'LOG_ADHERENCE', y='LOG_HDWY_DEV');

# %%
headway_df[['ADHERENCE','SCHEDULED_HDWY','ACTUAL_HDWY','HDWY_DEV','LOG_ADHERENCE','LOG_SCHEDULED_HDWY','LOG_ACTUAL_HDWY','LOG_HDWY_DEV']].corr()
# Out:
#                     ADHERENCE  SCHEDULED_HDWY  ACTUAL_HDWY  HDWY_DEV  \
# ADHERENCE            1.000000        0.034318    -0.074719 -0.206794
# SCHEDULED_HDWY       0.034318        1.000000     0.862633  0.041296
# ACTUAL_HDWY         -0.074719        0.862633     1.000000  0.541023
# HDWY_DEV            -0.206794        0.041296     0.541023  1.000000
# LOG_ADHERENCE        0.661615        0.037605     0.001019 -0.090739
# LOG_SCHEDULED_HDWY   0.049385        0.812043     0.711841  0.039060
# LOG_ACTUAL_HDWY     -0.013954        0.539959     0.703353  0.499514
# LOG_HDWY_DEV        -0.355574       -0.016739     0.301547  0.579606
#
#                     LOG_ADHERENCE  LOG_SCHEDULED_HDWY  LOG_ACTUAL_HDWY  \
# ADHERENCE                0.661615            0.049385        -0.013954
# SCHEDULED_HDWY           0.037605            0.812043         0.539959
# ACTUAL_HDWY              0.001019            0.711841         0.703353
# ...

# %%
headway_df['HDWY_DEV_PCT'] = 100 * headway_df['HDWY_DEV']/headway_df['SCHEDULED_HDWY']
headway_df['LOG_HDWY_DEV_PCT'] = np.log(headway_df['HDWY_DEV_PCT'])
sns.scatterplot(data=headway_df, x= 'ADHERENCE', y='LOG_HDWY_DEV_PCT');
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
headway_df[['ADHERENCE','SCHEDULED_HDWY','ACTUAL_HDWY','HDWY_DEV','LOG_ADHERENCE','LOG_SCHEDULED_HDWY','LOG_ACTUAL_HDWY','LOG_HDWY_DEV','HDWY_DEV_PCT','LOG_HDWY_DEV_PCT']].corr()
# Out:
#                     ADHERENCE  SCHEDULED_HDWY  ACTUAL_HDWY  HDWY_DEV  \
# ADHERENCE            1.000000        0.034318    -0.074719 -0.206794
# SCHEDULED_HDWY       0.034318        1.000000     0.862633  0.041296
# ACTUAL_HDWY         -0.074719        0.862633     1.000000  0.541023
# HDWY_DEV            -0.206794        0.041296     0.541023  1.000000
# LOG_ADHERENCE        0.661615        0.037605     0.001019 -0.090739
# LOG_SCHEDULED_HDWY   0.049385        0.812043     0.711841  0.039060
# LOG_ACTUAL_HDWY     -0.013954        0.539959     0.703353  0.499514
# LOG_HDWY_DEV        -0.355574       -0.016739     0.301547  0.579606
# HDWY_DEV_PCT        -0.203726       -0.009870     0.399671  0.805787
# LOG_HDWY_DEV_PCT    -0.342319       -0.290979     0.049957  0.519807
#
#                     LOG_ADHERENCE  LOG_SCHEDULED_HDWY  LOG_ACTUAL_HDWY  \
# ADHERENCE                0.661615            0.049385        -0.013954
# ...

# %% [markdown]
# **After trying many different transformations of the data, visualizing the data, and calculating correlation coefficients, I think it is fairly safe to say that there is no correlation between adherence and headway.**

# %%
sns.regplot(data=headway_df[headway_df['HDWY_DEV_PCT']!=np.inf], x= 'ADHERENCE', y='HDWY_DEV_PCT', line_kws={'color':'grey'});

# %%
sns.scatterplot(data=headway_df, x= 'LOG_ADHERENCE', y='LOG_HDWY_DEV_PCT');
